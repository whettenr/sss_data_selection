# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# # Medium DS

# %%
# csv file path
fp = "/local_disk/apollon/rwhetten/loquacious_medium_train.csv"
# load in df
df = pd.read_csv(fp)
# sort
df.sort_values(["duration"], ascending=False, inplace=True)

# get longest files until total duration = total_audio_sec
total_hours = 1249
total_audio_sec = total_hours * 3600
# Out:
# /tmp/ipykernel_2062/3871526415.py:4: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp)

# %%
selected_files = []
current_duration = 0
limit = 32
# Iterate through the sorted DataFrame
for index, row in tqdm(df.iterrows(), total=len(df), desc="Processing files"):
    # Check if adding the current file's duration will exceed the total
    if current_duration + row['duration'] <= total_audio_sec:
        # If not, add the file to the selected list and update the duration
        if row['duration'] <= limit:
            selected_files.append(row)
            current_duration += row['duration']
    else:
        # If it will exceed, stop the loop since we have the longest files
        # and adding more would be counterproductive
        break

# Create a new DataFrame from the selected files
selected_df = pd.DataFrame(selected_files)

# Print the final result
print(f"Total files selected: {len(selected_df)}")
print(f"Total duration of selected files: {current_duration:.2f} seconds")
# print(selected_df.head())

selected_df.to_csv(f"/local_disk/apollon/rwhetten/sss_data_selection/sample/csvs/loq_medium/length_under_{str(limit)}_sec_0.5.csv", index=False)
# Out:
# Processing files:  26%|▎| 283054/1074114 [00:29<01:23, 9467.53it/s]
# Total files selected: 282295
# Total duration of selected files: 4496397.88 seconds

# %%
selected_files = []
current_duration = 0
limit = 25
# Iterate through the sorted DataFrame
for index, row in tqdm(df.iterrows(), total=len(df), desc="Processing files"):
    # Check if adding the current file's duration will exceed the total
    if current_duration + row['duration'] <= total_audio_sec:
        # If not, add the file to the selected list and update the duration
        if row['duration'] <= limit:
            selected_files.append(row)
            current_duration += row['duration']
    else:
        # If it will exceed, stop the loop since we have the longest files
        # and adding more would be counterproductive
        break

# Create a new DataFrame from the selected files
selected_df = pd.DataFrame(selected_files)

# Print the final result
print(f"Total files selected: {len(selected_df)}")
print(f"Total duration of selected files: {current_duration:.2f} seconds")
# print(selected_df.head())

selected_df.to_csv(f"/local_disk/apollon/rwhetten/sss_data_selection/sample/csvs/loq_medium/length_under_{str(limit)}_sec_0.5.csv", index=False)
# Out:
# Processing files:  30%|▎| 324880/1074114 [00:34<01:19, 9441.08it/s]
# Total files selected: 309777
# Total duration of selected files: 4496397.31 seconds

# %%
file = f"/local_disk/apollon/rwhetten/sss_data_selection/sample/csvs/loq_medium/length_under_25_sec_0.5.csv"
df = pd.read_csv(file)
print(df.duration.sum()/3600)
df.duration.describe()
# Out:
# 1248.9992527894506
# count    309777.000000
# mean         14.514949
# std           3.061114
# min           9.179937
# 25%          12.599000
# 50%          14.710000
# 75%          15.000000
# max          25.000000
# Name: duration, dtype: float64

# %%
file = f"/local_disk/apollon/rwhetten/sss_data_selection/sample/csvs/loq_medium/length_under_32_sec_0.5.csv"
df = pd.read_csv(file)
print(df.duration.sum()/3600)
df.duration.describe()
# Out:
# 1248.9994117013885
# count    282295.000000
# mean         15.928011
# std           3.938742
# min          10.670000
# 25%          14.260000
# 50%          14.830000
# 75%          16.640000
# max          32.000000
# Name: duration, dtype: float64

# %% [markdown]
# # Large DS

# %%
# csv file path
fp = "/local_disk/apollon/rwhetten/loquacious_large_train.csv"
# load in df
df = pd.read_csv(fp)
# sort
df.sort_values(["duration"], ascending=False, inplace=True)

# get longest files until total duration = total_audio_sec
total_hours = 12601
total_audio_sec = total_hours * 3600
# Out:
# /tmp/ipykernel_2062/1968358836.py:4: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(fp)

# %%
df.duration.hist(bins=40)
# Out:
# <Axes: >

# %%
df.duration.sum() / 3600
# Out:
# 25204.902253320193

# %%
selected_files = []
current_duration = 0
limit = 32
# Iterate through the sorted DataFrame
for index, row in tqdm(df.iterrows(), total=len(df), desc="Processing files"):
    # Check if adding the current file's duration will exceed the total
    if current_duration + row['duration'] <= total_audio_sec:
        # If not, add the file to the selected list and update the duration
        if row['duration'] <= limit:
            selected_files.append(row)
            current_duration += row['duration']
    else:
        # If it will exceed, stop the loop since we have the longest files
        # and adding more would be counterproductive
        break

# Create a new DataFrame from the selected files
selected_df = pd.DataFrame(selected_files)

# Print the final result
print(f"Total files selected: {len(selected_df)}")
print(f"Total duration of selected files: {current_duration:.2f} seconds")
# print(selected_df.head())

selected_df.to_csv(f"/local_disk/apollon/rwhetten/sss_data_selection/sample/csvs/loq_large/length_under_{str(limit)}_sec_0.5.csv", index=False)
# Out:
# Processing files:  27%|▎| 2591760/9487877 [04:37<12:18, 9341.89it/s
# Total files selected: 2589882
# Total duration of selected files: 45363597.37 seconds

# %%
selected_files = []
current_duration = 0
limit = 25
# Iterate through the sorted DataFrame
for index, row in tqdm(df.iterrows(), total=len(df), desc="Processing files"):
    # Check if adding the current file's duration will exceed the total
    if current_duration + row['duration'] <= total_audio_sec:
        # If not, add the file to the selected list and update the duration
        if row['duration'] <= limit:
            selected_files.append(row)
            current_duration += row['duration']
    else:
        # If it will exceed, stop the loop since we have the longest files
        # and adding more would be counterproductive
        break

# Create a new DataFrame from the selected files
selected_df = pd.DataFrame(selected_files)

# Print the final result
print(f"Total files selected: {len(selected_df)}")
print(f"Total duration of selected files: {current_duration:.2f} seconds")
# print(selected_df.head())

selected_df.to_csv(f"/local_disk/apollon/rwhetten/sss_data_selection/sample/csvs/loq_large/length_under_{str(limit)}_sec_0.5.csv", index=False)
# Out:
# Processing files:  33%|▎| 3113353/9487877 [05:28<11:11, 9489.63it/s
# Total files selected: 2865123
# Total duration of selected files: 45363590.64 seconds

# %%
file = f"/local_disk/apollon/rwhetten/sss_data_selection/sample/csvs/loq_large/length_under_25_sec_0.5.csv"
df = pd.read_csv(file)
print(df.duration.sum()/3600)
df.duration.describe()
# Out:
# /tmp/ipykernel_2062/2480808023.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# 12600.997399548613
# count    2.865123e+06
# mean     1.583303e+01
# std      2.221262e+00
# min      1.261994e+01
# 25%      1.461000e+01
# 50%      1.489000e+01
# 75%      1.688000e+01
# max      2.500000e+01
# Name: duration, dtype: float64

# %%
file = f"/local_disk/apollon/rwhetten/sss_data_selection/sample/csvs/loq_large/length_under_32_sec_0.5.csv"
df = pd.read_csv(file)
print(df.duration.sum()/3600)
df.duration.describe()
# Out:
# /tmp/ipykernel_2062/445567967.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# 12600.99927069445
# count    2.589882e+06
# mean     1.751570e+01
# std      4.322162e+00
# min      1.444000e+01
# 25%      1.482000e+01
# 50%      1.500000e+01
# 75%      1.875900e+01
# max      3.200000e+01
# Name: duration, dtype: float64
